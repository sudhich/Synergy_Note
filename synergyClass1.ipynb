# %%
print("line 1")
print("line 2")
print("line 3")
# Out:
# line 1
# line 2
# line 3

# %%
# print("line 1")
print("line 2")
print("line 3")
# Out:
# line 2
# line 3

# %%
# print("line 1")
print("line 2")
#print("line 3")
# Out:
# line 2

# %%
"""
print("line 1")
print("line 2")
print("line 3")
"""
print("line 4")
# Out:
# line 4

# %%
# !python --version
# Out:
# Python 3.13.5

# %%
A=20

# %%
print(A)
# Out:
# 20

# %%
a=10
b=20
print(a+b)
# Out:
# 30

# %%
a=str(a)
b=str(b)
print(a+b)
# Out:
# 1020

# %%
a=20.7
b=67
print(a+b)
# Out:
# 87.7

# %%
print("Hellow world")
# Out:
# Hellow world

# %%
print(a,b)
# Out:
# 20.7 67

# %%
print(a,b,"Hello")
# Out:
# 20.7 67 Hello

# %%
print("hi",end="-")
print("Hellow")
print("hi",end="-")
print("Hellow")
# Out:
# hi-Hellow
# hi-Hellow

# %%
print("hi","Hellow",sep=" ")
# Out:
# hi Hellow

# %%
print("hi","Hellow",sep="@",end=" ")
print("Aman")
# Out:
# hi@Hellow Aman

# %%
a=input("Enter the input")
print(a+a)
# Out:
# Enter the input10
# 1010

# %%
a=int(input("Enter the input"))
print(a+a)
# Out:
# Enter the input10
# 20

# %%
a=float(input("Enter the input"))
print(a+a)
# Out:
# Enter the input20.4
# 40.8

# %%
x = 10        # int
y = 3.14      # float
z = 2 + 3j    # complex
print(x,y,z)
print(z.real,z.imag)
# Out:
# 10 3.14 (2+3j)
# 2.0 3.0

# %%
string="suchi"
print(string)
# Out:
# suchi

# %%
string='suchi'
print(string)
# Out:
# suchi

# %%
str1="""
Line1
Line2
Line3
"""
print(str1)
# Out:
# Line1
# Line2
# Line3

# %%
str1='''
Line1
Line2
Line3
'''
print(str1)
# Out:
# Line1
# Line2
# Line3

# %%
print(True)
print(False)
# Out:
# True
# False

# %%
print(True+True-False+True)
# Out:
# 3

# %%
List=["Apple","Orange",23.67,89]
print(List)
# Out:
# ['Apple', 'Orange', 23.67, 89]

# %%
tuple1=("Apple","Orange",23.67,89)
print(tuple1)
# Out:
# ('Apple', 'Orange', 23.67, 89)

# %%
dict1={"Name":"Sudhir","Age":700}
print(dict1)
# Out:
# {'Name': 'Sudhir', 'Age': 700}

# %%
set1={1,2,3,3,4}
print(set1)
# Out:
# {1, 2, 3, 4}

# %%
b=None
print(b)
# Out:
# None

# %% [markdown]
# # Class-2

# %%
 1+6
# Out:
# 7

# %%
7-3
# Out:
# 4

# %%
4*4
# Out:
# 16

# %%
4/3
# Out:
# 1.3333333333333333

# %%
4//3
# Out:
# 1

# %%
2**4
# Out:
# 16

# %%
3%2
# Out:
# 1

# %%
2%5
# Out:
# 2

# %%
20%5
# Out:
# 0

# %%
16%3
# Out:
# 1

# %%
16%17
# Out:
# 16

# %%
29>27
# Out:
# True

# %%
29<27
# Out:
# False

# %%
30==69
# Out:
# False

# %%
60==60
# Out:
# True

# %%
30>=30
# Out:
# True

# %%
30<=30
# Out:
# True

# %%
49!=69
# Out:
# True

# %%
50!=50
# Out:
# False

# %%
age=70
dress=True
age>50 and dress
# Out:
# True

# %%
age=70
dress=False
age>50 and dress
# Out:
# False

# %%
age=70
dress=True
age>50 or dress
# Out:
# True

# %%
age=30
dress=True
age>50 or dress
# Out:
# True

# %%
age=30
dress=False
age>50 or dress
# Out:
# False

# %%
not False
# Out:
# True

# %%
2&3
# Out:
# 2

# %%
2|3
# Out:
# 3

# %%
a=5 #101
b=3 #011
    #110
print(a^b)
# Out:
# 6

# %%
print(3>>2)
# Out:
# 0

# %%
5<<1
# Out:
# 10

# %%
a=30
a is 30
# Out:
# <>:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\sudhir\AppData\Local\Temp\ipykernel_12432\2740979668.py:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   a is 30
# True

# %%
a=30
a is not 300
# Out:
# <>:2: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:2: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# C:\Users\sudhir\AppData\Local\Temp\ipykernel_12432\456226367.py:2: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   a is not 300
# True

# %%
10 in [10,20,30]
# Out:
# True

# %%
100 not in [10,20,30]
# Out:
# True

# %%
20+38/2
# Out:
# 39.0

# %%
2**2**3
# Out:
# 256

# %%
2**3
# Out:
# 8

# %%
2**8
# Out:
# 256

# %%
age = 17
if age >= 18:
    print("You can vote")
else:
    print("You cannot vote")
# Out:
# You cannot vote

# %% [markdown]
# # Class-3

# %%
L=[10,20,"sudhir",60.56,"sudhir"]
print(L)
# Out:
# [10, 20, 'sudhir', 60.56, 'sudhir']

# %%
print(L[1])
print(L[-3])
# Out:
# 20
# sudhir

# %%
print(L)
L[2]="Deepak"
print(L)
# Out:
# [10, 20, 'sudhir', 60.56, 'sudhir']
# [10, 20, 'Deepak', 60.56, 'sudhir']

# %%
#L[start:end:step]
print(L[2:4])
# Out:
# ['Deepak', 60.56]

# %%
print(L[:])
# Out:
# [10, 20, 'Deepak', 60.56, 'sudhir']

# %%
print(L[0:4])
# Out:
# [10, 20, 'Deepak', 60.56]

# %%
print(L[0:4:2])
# Out:
# [10, 'Deepak']

# %%
print(L)
print(L[::2])
# Out:
# [10, 20, 'Deepak', 60.56, 'sudhir']
# [10, 'Deepak', 'sudhir']

# %%
print(L)
print(L[::3])
# Out:
# [10, 20, 'Deepak', 60.56, 'sudhir']
# [10, 60.56]

# %%
print(L)
print(L[0:3])
print(L[-5:-2])
# Out:
# [10, 20, 'Deepak', 60.56, 'sudhir']
# [10, 20, 'Deepak']
# [10, 20, 'Deepak']

# %%
print(L)
L.append("Lipsa")
L.append(29)
print(L)
# Out:
# [10, 20, 'Deepak', 60.56, 'sudhir']
# [10, 20, 'Deepak', 60.56, 'sudhir', 'Lipsa', 29]

# %%
print(L)
L.insert(2,"Jasoswani")
L.insert(-1,27)
print(L)
# Out:
# [10, 20, 'Deepak', 60.56, 'sudhir', 'Lipsa', 29]
# [10, 20, 'Jasoswani', 'Deepak', 60.56, 'sudhir', 'Lipsa', 27, 29]

# %%
print(L)
# Out:
# [10, 20, 'Jasoswani', 'Deepak', 60.56, 'sudhir', 'Lipsa', 27, 29]

# %%
L.insert(3,"arya")
print(L)
# Out:
# [10, 20, 'Jasoswani', 'arya', 'Deepak', 60.56, 'sudhir', 'Lipsa', 27, 29]

# %%
L[4]="Tulsi"
print(L)
# Out:
# [10, 20, 'Jasoswani', 'arya', 'Tulsi', 60.56, 'sudhir', 'Lipsa', 27, 29]

# %%
print(L[3:6])
# Out:
# ['arya', 'Tulsi', 60.56]

# %%
print(L[7])
# Out:
# Lipsa

# %%
l1=[10,20,30]
l2=[30,59,80]
l3=l1+l2
print(l3)
# Out:
# [10, 20, 30, 30, 59, 80]

# %%
[27,38]+[49,82]+[20,49,81]
# Out:
# [27, 38, 49, 82, 20, 49, 81]

# %%
print(L)
L.append([29,30])
print(L)
# Out:
# [10, 20, 'Jasoswani', 'arya', 'Tulsi', 60.56, 'sudhir', 'Lipsa', 27, 29]
# [10, 20, 'Jasoswani', 'arya', 'Tulsi', 60.56, 'sudhir', 'Lipsa', 27, 29, [29, 30]]

# %%
print(L)
L.extend([29,30])
print(L)
# Out:
# [10, 20, 'Jasoswani', 'arya', 'Tulsi', 60.56, 'sudhir', 'Lipsa', 27, 29, [29, 30]]
# [10, 20, 'Jasoswani', 'arya', 'Tulsi', 60.56, 'sudhir', 'Lipsa', 27, 29, [29, 30], 29, 30]

# %%
print(L)
L.remove('sudhir')
print(L)
# Out:
# [10, 20, 'Jasoswani', 'arya', 'Tulsi', 60.56, 'sudhir', 'Lipsa', 27, 29, [29, 30], 29, 30]
# [10, 20, 'Jasoswani', 'arya', 'Tulsi', 60.56, 'Lipsa', 27, 29, [29, 30], 29, 30]

# %%
print(L)
L.remove(29)
print(L)
# Out:
# [10, 20, 'Jasoswani', 'arya', 'Tulsi', 60.56, 'Lipsa', 27, 29, [29, 30], 29, 30]
# [10, 20, 'Jasoswani', 'arya', 'Tulsi', 60.56, 'Lipsa', 27, [29, 30], 29, 30]

# %%
print(L)
L.pop(3)
print(L)
# Out:
# [10, 20, 'Jasoswani', 'arya', 'Tulsi', 60.56, 'Lipsa', 27, [29, 30], 29, 30]
# [10, 20, 'Jasoswani', 'Tulsi', 60.56, 'Lipsa', 27, [29, 30], 29, 30]

# %%
print(L)
L.clear()
print(L)
# Out:
# [10, 20, 'Jasoswani', 'Tulsi', 60.56, 'Lipsa', 27, [29, 30], 29, 30]
# []

# %% [markdown]
# # Class-4
# # List

# %%
#2,4,5,0,-3,59
#acc -3,0,2,4,5,59
#decc 59,5,2,0,-3
l3=[2,4,5,0,-3,59]
print(l3)
l3.sort()
print(l3)
# Out:
# [2, 4, 5, 0, -3, 59]
# [-3, 0, 2, 4, 5, 59]

# %%
l3=[2,4,5,0,-3,59]
print(l3)
l3.sort(reverse=True)
print(l3)
# Out:
# [2, 4, 5, 0, -3, 59]
# [59, 5, 4, 2, 0, -3]

# %%
l3=[2,4,5,0,-3,59]
print(l3)
l3.reverse()
print(l3)
# Out:
# [2, 4, 5, 0, -3, 59]
# [59, -3, 0, 5, 4, 2]

# %%
l3=[2,4,5,0,-3,59,2,4,2]
print(l3.count(4))
print(l3.count(2))
print(l3.count(0))
print(len(l3))
# Out:
# 2
# 3
# 1
# 9

# %%
l3.index(5)
# Out:
# 2

# %%
l3.index(2)
# Out:
# 0

# %%
print(l3)
l4=l3.copy()
print(l4)
# Out:
# [2, 4, 5, 0, -3, 59, 2, 4, 2]
# [2, 4, 5, 0, -3, 59, 2, 4, 2]

# %% [markdown]
# # Tuple

# %%
t1=(10,20.59,"akash",10,20.59,"akash")
print(t1)
# Out:
# (10, 20.59, 'akash', 10, 20.59, 'akash')

# %%
print(t1[2])
print(t1[-1])
# Out:
# akash
# akash

# %%
t1[2]="Akash"
#That is the reason tuple is immutable.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8408\1503813957.py in <module>
# ----> 1 t1[2]="Akash"
#
# TypeError: 'tuple' object does not support item assignment

# %%
print(t1.count(20.59))
# Out:
# 2

# %%
print(t1.index('akash'))
# Out:
# 2

# %%
s1={10,20,30.50,"sudhi",10,10,20,30.50,"sudhi"}
print(s1)
# Out:
# {10, 'sudhi', 20, 30.5}

# %%
print(s1[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8408\1795753602.py in <module>
# ----> 1 print(s1[1])
#
# TypeError: 'set' object is not subscriptable

# %%
s1={10,20,30}
s3={30,40,50}
print(s1.union(s3))
# Out:
# {50, 20, 40, 10, 30}

# %%
print(s1.intersection(s3))
# Out:
# {30}

# %%
print(s1)
s1.add(900)
print(s1)
# Out:
# {900, 10, 20, 30}
# {900, 10, 20, 30}

# %% [markdown]
# # Home work
# #### Perform all operation in set

# %%
s1.

# %%
# Name="Surya"
# Roll_no=123
# age=20
# Weight=60
d1={"Name":"Surya","Roll_no":123,"age":20,"Weight":60.68}
print(d1)
# Out:
# {'Name': 'Surya', 'Roll_no': 123, 'age': 20, 'Weight': 60.68}

# %%
print(d1["Name"])
# Out:
# Surya

# %%
print(d1["Roll_no"])
# Out:
# 123

# %% [markdown]
# print(d1)
# d1["Name"]="Lipsa"
# print(d1)

# %%
api={"request":"https://www.geeksforgeeks.org/python/abstract-classes-in-python/m",
     "response":"Abstract Classes in Python"
    }
print(api)
# Out:
# {'request': 'https://www.geeksforgeeks.org/python/abstract-classes-in-python/m', 'response': 'Abstract Classes in Python'}

# %% [markdown]
# # Home work
# #### Perform all operation in dict

# %%
d1.

# %%
print(d1)
print(d1.keys())
# Out:
# {'Name': 'Lipsa', 'Roll_no': 123, 'age': 20, 'Weight': 60.68}
# dict_keys(['Name', 'Roll_no', 'age', 'Weight'])

# %%
print(d1)
print(d1.items())
# Out:
# {'Name': 'Lipsa', 'Roll_no': 123, 'age': 20, 'Weight': 60.68}
# dict_items([('Name', 'Lipsa'), ('Roll_no', 123), ('age', 20), ('Weight', 60.68)])

# %%
print(d1)
print(d1.values())
# Out:
# {'Name': 'Lipsa', 'Roll_no': 123, 'age': 20, 'Weight': 60.68}
# dict_values(['Lipsa', 123, 20, 60.68])
